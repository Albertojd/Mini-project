# %%
import words
import random
import string
gallows = ['''
      +---+
      |   |
          |
          |
          |
          |
    =========''', '''
      +---+
      |   |
      O   |
          |
          |
          |
    =========''', '''
      +---+
      |   |
      O   |
      |   |
          |
          |
    =========''', '''
      +---+
      |   |
      O   |
     /|   |
          |
          |
    =========''', '''
      +---+
      |   |
      O   |
     /|\  |
          |
          |
    =========''', '''
      +---+
      |   |
      O   |
     /|\  |
     /    |
          |
    =========''', '''
      +---+
      |   |
      O   |
     /|\  |
     / \  |
          |
    =========
    YOU LOST''']
word_list = ["python", 'ironhack', 'dog', 'cat', 'mint', 'earth', 'bottle', 'book', 'android', 'pen',
         'computer', 'glasses', 'cork', 'bicycle', 'guitar', 'screwdriver',"ball", "headphones", "screen", "windows", "usb"]

chosen_word = random.choice(word_list) ##Elige una palbra aletoriamente
print(chosen_word)


mistake = 0  ### Varaible para contabilizar errores
progress = []  ### Lista que se rellenará con espacios en blancos, para luego ir incluyendo las letras acertadas
count_letters= len(chosen_word) ### Esto nos ayuda a pintar el número de letras que tiene la palabra oculta
alphabet= list(string.ascii_lowercase)

for i in range(len(chosen_word)): ### Este bucle rellena la lista de progreso con los espacios en blanco correspondientes
    progress.append("_ ")

check_word = [] ### Nos ayudará a comprobar si coincide la palabra escrita con la elegida por el programa
for char in chosen_word:
    check_word.append(char+" ")
used_letters=[]

while mistake < 7: ### Mantiene el juego activo hasta que tengamos 7 fallos, el programa pinta al ahorcado
    if mistake == 0:
        print(gallows[0])
    elif mistake == 1:
        print(gallows[1])
    elif mistake == 2:
        print(gallows[2])
    elif mistake == 3:
        print(gallows[3])
    elif mistake == 4:
        print(gallows[4])
    elif mistake == 5:
        print(gallows[5])
    elif mistake == 6:
        print(gallows[6])
        break
    
    
    print("".join(progress)) ###Convertimos la lista, en un string, y la pintamos
    print("The word has ",count_letters, "letters")  ### Con esto ayudamos a ver cuantas letras tiene la palabra oculta
    print("Used letters: ", used_letters)  ### Pinta las letras que ya has usado
    letter= input("Choose a lowercase letter:")
    if letter in used_letters:
        print("You have already used this letter")
    if letter not in alphabet:
        print("This character is not allowed")
    else:
        used_letters.append(letter)
        
        wrong = True  ##Sí la letra está mal
        for i in range(len(chosen_word)):
            if letter == chosen_word[i]:
                progress[i]= letter + " "
                wrong = False
        
        if wrong:
            mistake += 1
    
        if check_word == progress:
            print("".join(progress))
            print("YOU WIN!, The word is: ", chosen_word.upper())
            break

# %%
import random
import string
from words import home
gallows = ['''
      +---+
      |   |
          |
          |
          |
          |
    =========''', '''
      +---+
      |   |
      O   |
          |
          |
          |
    =========''', '''
      +---+
      |   |
      O   |
      |   |
          |
          |
    =========''', '''
      +---+
      |   |
      O   |
     /|   |
          |
          |
    =========''', '''
      +---+
      |   |
      O   |
     /|\  |
          |
          |
    =========''', '''
      +---+
      |   |
      O   |
     /|\  |
     /    |
          |
    =========''', '''
      +---+
      |   |
      O   |
     /|\  |
     / \  |
          |
    =========
    YOU LOST''']

def randomword(x):
    w = random.choice(x)
    count_letters= len(w)
    return w.upper()
chosen_word = randomword(home)
print(chosen_word)

def game_progress():
    progress = []
    for i in range(len(chosen_word)): ### Este bucle rellena la lista de progreso con los espacios en blanco correspondientes
        progress.append("_ ")
    return progress

hide_word = game_progress()
mistake = 0  ### Varaible para contabilizar errores
progress = []  ### Lista que se rellenará con espacios en blancos, para luego ir incluyendo las letras acertadas
count_letters= len(chosen_word) ### Esto nos ayuda a pintar el número de letras que tiene la palabra oculta
alphabet= list(string.ascii_uppercase)

for i in range(len(chosen_word)): ### Este bucle rellena la lista de progreso con los espacios en blanco correspondientes
    progress.append("_ ")

def checking():
    check_list= [] ### Nos ayudará a comprobar si coincide la palabra escrita con la elegida por el programa
    for char in chosen_word:
        check_list.append(char+" ")
    return check_list

check_word = checking()        
used_letters=[]

while mistake < 7: ### Mantiene el juego activo hasta que tengamos 7 fallos, el programa pinta al ahorcado
    if mistake == 0:
        print(gallows[0])
    elif mistake == 1:
        print(gallows[1])
    elif mistake == 2:
        print(gallows[2])
    elif mistake == 3:
        print(gallows[3])
    elif mistake == 4:
        print(gallows[4])
    elif mistake == 5:
        print(gallows[5])
    elif mistake == 6:
        print(gallows[6])
        break
    
    
    print("".join(progress)) ###Convertimos la lista, en un string, y la pintamos
    print("The word has ",count_letters, "letters")  ### Con esto ayudamos a ver cuantas letras tiene la palabra oculta
    print("Used letters: ", used_letters)  ### Pinta las letras que ya has usado
    letter= input("Choose a uppercase letter:")
    if letter in used_letters:
        print("You have already used this letter")
    if letter not in alphabet:
        print("This character is not allowed")
    else:
        used_letters.append(letter)
        
        wrong = True  ##Sí la letra está mal
        for i in range(len(chosen_word)):
            if letter == chosen_word[i]:
                progress[i]= letter + " "
                wrong = False
        
        if wrong:
            mistake += 1
    
        if check_word == progress:
            print("".join(progress))
            print("YOU WIN!, The word is: ", chosen_word.upper())
            break

# %%
import random
import string
from words import animals
from words import python
gallows = ['''
      +---+
      |   |
          |
          |
          |
          |
    =========''', '''
      +---+
      |   |
      O   |
          |
          |
          |
    =========''', '''
      +---+
      |   |
      O   |
      |   |
          |
          |
    =========''', '''
      +---+
      |   |
      O   |
     /|   |
          |
          |
    =========''', '''
      +---+
      |   |
      O   |
     /|\  |
          |
          |
    =========''', '''
      +---+
      |   |
      O   |
     /|\  |
     /    |
          |
    =========''', '''
      +---+
      |   |
      O   |
     /|\  |
     / \  |
          |
    =========
    YOU LOST''']

def randomword(x, y):    
    while True:
        theme = input("Choose theme: "+"\x1b[1;30m"+"animals,   python ==>")
        if theme == "python":
            chosens = random.choice(x)
            count_letters= len(chosens)
            break
        elif theme == "animals":
            chosens = random.choice(y)
            count_letters= len(chosens)
            break
        else: 
            print("WRONG, please choose a valid option ")           
    return chosens.upper()

chosen_word = randomword(python, animals)

def game_progress():
    progress = []
    for i in range(len(chosen_word)): ### Este bucle rellena la lista de progreso con los espacios en blanco correspondientes
        progress.append("_ ")
    return progress

hide_word = game_progress()
mistake = 0  ### Varaible para contabilizar errores
progress = []  ### Lista que se rellenará con espacios en blancos, para luego ir incluyendo las letras acertadas
count_letters= len(chosen_word) ### Esto nos ayuda a pintar el número de letras que tiene la palabra oculta
alphabet= list(string.ascii_uppercase)

for i in range(len(chosen_word)): ### Este bucle rellena la lista de progreso con los espacios en blanco correspondientes
    progress.append("_ ")

def checking():
    check_list= [] ### Nos ayudará a comprobar si coincide la palabra escrita con la elegida por el programa
    for char in chosen_word:
        check_list.append(char+" ")
    return check_list

check_word = checking()        
used_letters=[]

while mistake < 7: ### Mantiene el juego activo hasta que tengamos 7 fallos, el programa pinta al ahorcado
    if mistake == 0:
        print(gallows[0])
    elif mistake == 1:
        print(gallows[1])
    elif mistake == 2:
        print(gallows[2])
    elif mistake == 3:
        print(gallows[3])
    elif mistake == 4:
        print(gallows[4])
    elif mistake == 5:
        print(gallows[5])
    elif mistake == 6:
        print(gallows[6])
        break
    
    
    print("".join(progress)) ###Convertimos la lista, en un string, y la pintamos
    print("The word has ",count_letters, "letters")  ### Con esto ayudamos a ver cuantas letras tiene la palabra oculta
    print("Used letters: ", used_letters)  ### Pinta las letras que ya has usado
    letter= input("Choose a uppercase letter:")
    if letter in used_letters:
        print("You have already used this letter")
    if letter not in alphabet:
        print("This character is not allowed")
    else:
        used_letters.append(letter)
        
        wrong = True  ##Sí la letra está mal
        for i in range(len(chosen_word)):
            if letter == chosen_word[i]:
                progress[i]= letter + " "
                wrong = False
        
        if wrong:
            mistake += 1
    
        if check_word == progress:
            print("".join(progress))
            print("YOU WIN!, The word is: ", chosen_word.upper())
            break
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-774b0174fdd1> in <module>
#       1 import random
#       2 import string
# ----> 3 from words import animals
#       4 from words import python
#       5 gallows = ['''
#
# ImportError: cannot import name 'animals' from 'words' (C:\Users\alber\IRONHACK\proyectos\mini-project\game\words.py)

# %%
import random
import string
from words import home
from words import python

def randomword(x, y):
    theme = input("choose the theme: ")
    if theme == "python":
        chosens = random.choice(x)
        count_letters= len(chosens)
    elif theme == "home":
        chosens = random.choice(y)
        count_letters= len(chosens)
    return chosens
chosen_word = randomword(python, home)
print(chosen_word)

# %%
print("\x1b[1;30m"+"Texto en negrita de color amarillo")
